# %%
import pandas as pd

# %%
data=pd.read_excel("Telco-Customer-Churn.xlsx")
data
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# 1. a. Gender

# %%
data["gender"].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
data["Churn"]=="No"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7038     True
# 7039     True
# 7040     True
# 7041    False
# 7042     True
# Name: Churn, Length: 7043, dtype: bool

# %%
d1=data[data["Churn"]=="No"]
d1
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 6     1452-KIOVK    Male              0  ...          89.10      1949.40     No
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
d1["gender"].value_counts()
# Out:
# Male      2625
# Female    2549
# Name: gender, dtype: int64

# %% [markdown]
# 1. b. Citizenship

# %%
data["SeniorCitizen"].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
d1["SeniorCitizen"].value_counts()
# Out:
# 0    4508
# 1     666
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# 2. a. Gender

# %%
data["Churn"]=="Yes"
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: Churn, Length: 7043, dtype: bool

# %%
d2=data[data["Churn"]=="Yes"]
d2
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# 13    0280-XJGEX    Male              0  ...         103.70      5036.30    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7021  1699-HPSBG    Male              0  ...          59.80       727.80    Yes
# 7026  8775-CEBBJ  Female              0  ...          44.20       403.35    Yes
# 7032  6894-LFHLY    Male              1  ...          75.75        75.75    Yes
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
#
# ...

# %%
d2["gender"].value_counts()
# Out:
# Female    939
# Male      930
# Name: gender, dtype: int64

# %% [markdown]
# 2. b. Citizenship

# %%
d2["SeniorCitizen"].value_counts()
# Out:
# 0    1393
# 1     476
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# 3. a. Payment method based on churn

# %%
data["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
d1["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
d1["PaymentMethod"].value_counts()
# Out:
# Mailed check                 1304
# Electronic check             1294
# Credit card (automatic)      1290
# Bank transfer (automatic)    1286
# Name: PaymentMethod, dtype: int64

# %%
d2["PaymentMethod"].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
d2["PaymentMethod"].value_counts()
# Out:
# Electronic check             1071
# Mailed check                  308
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# 3. b. Payment method based on contract

# %%
data["Contract"].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
data["Contract"]=="Month-to-month"
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040     True
# 7041     True
# 7042    False
# Name: Contract, Length: 7043, dtype: bool

# %%
d3=data[data["Contract"]=="Month-to-month"]
d3
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 6     1452-KIOVK    Male              0  ...          89.10      1949.40     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7033  9767-FFLEM    Male              0  ...          69.50      2625.25     No
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7035  8456-QDAVC    Male              0  ...          78.70      1495.10     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
#
# ...

# %%
d3["PaymentMethod"].value_counts()
# Out:
# Electronic check             1850
# Mailed check                  893
# Bank transfer (automatic)     589
# Credit card (automatic)       543
# Name: PaymentMethod, dtype: int64

# %%
data["Contract"]=="Two year"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042     True
# Name: Contract, Length: 7043, dtype: bool

# %%
d4=data[data["Contract"]=="Two year"]
d4
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 11    7469-LKBCI    Male              0  ...          18.95       326.80     No
# 15    3655-SNQYZ  Female              0  ...         113.25      7895.15     No
# 17    9959-WOFKT    Male              0  ...         106.70      7382.25     No
# 23    3638-WEABW  Female              0  ...          59.90      3505.10     No
# 28    5248-YGIJN    Male              0  ...          90.25      6369.45     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7017  4807-IZYOZ  Female              0  ...          20.65      1020.75     No
# 7019  9710-NJERN  Female              0  ...          20.15       826.00     No
# 7028  9281-CEDRU  Female              0  ...          64.10      4326.25     No
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
d4["PaymentMethod"].value_counts()
# Out:
# Credit card (automatic)      581
# Bank transfer (automatic)    564
# Mailed check                 382
# Electronic check             168
# Name: PaymentMethod, dtype: int64

# %%
data["Contract"]=="One year"
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7038     True
# 7039     True
# 7040    False
# 7041    False
# 7042    False
# Name: Contract, Length: 7043, dtype: bool

# %%
d5=data[data["Contract"]=="One year"]
d5
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 9     6388-TABGU    Male              0  ...          56.15      3487.95     No
# 12    8091-TTVAX    Male              0  ...         100.35      5681.10     No
# 16    8191-XWSZG  Female              0  ...          20.65      1022.95     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7022  7203-OYKCT    Male              0  ...         104.95      7544.30     No
# 7031  3605-JISKB    Male              1  ...          60.00      3316.10     No
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
#
# ...

# %%
d5["PaymentMethod"].value_counts()
# Out:
# Credit card (automatic)      398
# Bank transfer (automatic)    391
# Electronic check             347
# Mailed check                 337
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# 4. Internet service

# %%
data['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
data["gender"] == "Male"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 7038     True
# 7039    False
# 7040    False
# 7041     True
# 7042     True
# Name: gender, Length: 7043, dtype: bool

# %%
d1
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 6     1452-KIOVK    Male              0  ...          89.10      1949.40     No
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
d1[data["gender"] == "Male"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE   Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW   Male              0  ...          42.30      1840.75     No
# 6     1452-KIOVK   Male              0  ...          89.10      1949.40     No
# 9     6388-TABGU   Male              0  ...          56.15      3487.95     No
# 10    9763-GRSKD   Male              0  ...          49.95       587.45     No
# ...          ...    ...            ...  ...            ...          ...    ...
# 7031  3605-JISKB   Male              1  ...          60.00      3316.10     No
# 7033  9767-FFLEM   Male              0  ...          69.50      2625.25     No
# ...

# %% [markdown]
# Internet service by males based on churn = no

# %%
d6=d1[data["gender"] == "Male"]
d6
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE   Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW   Male              0  ...          42.30      1840.75     No
# 6     1452-KIOVK   Male              0  ...          89.10      1949.40     No
# 9     6388-TABGU   Male              0  ...          56.15      3487.95     No
# 10    9763-GRSKD   Male              0  ...          49.95       587.45     No
# ...          ...    ...            ...  ...            ...          ...    ...
# 7031  3605-JISKB   Male              1  ...          60.00      3316.10     No
# 7033  9767-FFLEM   Male              0  ...          69.50      2625.25     No
# ...

# %%
d6['InternetService'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1               DSL
# 3               DSL
# 6       Fiber optic
# 9               DSL
# 10              DSL
#            ...
# 7031            DSL
# 7033    Fiber optic
# 7035    Fiber optic
# 7038            DSL
# 7042    Fiber optic
# Name: InternetService, Length: 2625, dtype: object>

# %%
data["gender"] == "Female"
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7038    False
# 7039     True
# 7040     True
# 7041    False
# 7042    False
# Name: gender, Length: 7043, dtype: bool

# %%
d1[data["gender"] == "Female"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# 15    3655-SNQYZ  Female              0  ...         113.25      7895.15     No
# 16    8191-XWSZG  Female              0  ...          20.65      1022.95     No
# 19    4183-MYFRB  Female              0  ...          90.05      1862.90     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7030  0871-OPBXW  Female              0  ...          20.05        39.25     No
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# ...

# %% [markdown]
# Internet service by females based on churn = no

# %%
d7=d1[data["gender"] == "Female"]
d7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# 15    3655-SNQYZ  Female              0  ...         113.25      7895.15     No
# 16    8191-XWSZG  Female              0  ...          20.65      1022.95     No
# 19    4183-MYFRB  Female              0  ...          90.05      1862.90     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7030  0871-OPBXW  Female              0  ...          20.05        39.25     No
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# ...

# %%
d7['InternetService'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0               DSL
# 7               DSL
# 15      Fiber optic
# 16               No
# 19      Fiber optic
#            ...
# 7030             No
# 7036            DSL
# 7037             No
# 7039    Fiber optic
# 7040            DSL
# Name: InternetService, Length: 2549, dtype: object>

# %%
d2
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# 13    0280-XJGEX    Male              0  ...         103.70      5036.30    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7021  1699-HPSBG    Male              0  ...          59.80       727.80    Yes
# 7026  8775-CEBBJ  Female              0  ...          44.20       403.35    Yes
# 7032  6894-LFHLY    Male              1  ...          75.75        75.75    Yes
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
#
# ...

# %%
d2[data["gender"] == "Male"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 2     3668-QPYBK   Male              0  ...          53.85       108.15    Yes
# 13    0280-XJGEX   Male              0  ...         103.70      5036.30    Yes
# 20    8779-QRDMV   Male              1  ...          39.65        39.65    Yes
# 22    1066-JKSGK   Male              0  ...          20.15        20.15    Yes
# 26    6467-CHFZW   Male              0  ...          99.35      4749.15    Yes
# ...          ...    ...            ...  ...            ...          ...    ...
# 7009  7703-ZEKEF   Male              0  ...          81.00      1917.10    Yes
# 7018  1122-JWTJW   Male              0  ...          70.65        70.65    Yes
# ...

# %% [markdown]
# Internet service by males based on churn = yes

# %%
d8=d2[data["gender"] == "Male"]
d8
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 2     3668-QPYBK   Male              0  ...          53.85       108.15    Yes
# 13    0280-XJGEX   Male              0  ...         103.70      5036.30    Yes
# 20    8779-QRDMV   Male              1  ...          39.65        39.65    Yes
# 22    1066-JKSGK   Male              0  ...          20.15        20.15    Yes
# 26    6467-CHFZW   Male              0  ...          99.35      4749.15    Yes
# ...          ...    ...            ...  ...            ...          ...    ...
# 7009  7703-ZEKEF   Male              0  ...          81.00      1917.10    Yes
# 7018  1122-JWTJW   Male              0  ...          70.65        70.65    Yes
# ...

# %%
d8['InternetService'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 2               DSL
# 13      Fiber optic
# 20              DSL
# 22               No
# 26      Fiber optic
#            ...
# 7009    Fiber optic
# 7018    Fiber optic
# 7021            DSL
# 7032    Fiber optic
# 7041    Fiber optic
# Name: InternetService, Length: 930, dtype: object>

# %%
d2[data["gender"] == "Female"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# 18    4190-MFLUW  Female              0  ...          55.20       528.35    Yes
# 29    8773-HHUOZ  Female              0  ...          64.70      1093.10    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7008  1980-KXVPM  Female              1  ...          75.05       256.25    Yes
# 7010  0723-DRCLG  Female              1  ...          74.45        74.45    Yes
# ...

# %% [markdown]
# Internet service by females based on churn = yes

# %%
d9=d2[data["gender"] == "Female"]
d9
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# 18    4190-MFLUW  Female              0  ...          55.20       528.35    Yes
# 29    8773-HHUOZ  Female              0  ...          64.70      1093.10    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7008  1980-KXVPM  Female              1  ...          75.05       256.25    Yes
# 7010  0723-DRCLG  Female              1  ...          74.45        74.45    Yes
# ...

# %%
d9['InternetService'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 4       Fiber optic
# 5       Fiber optic
# 8       Fiber optic
# 18              DSL
# 29              DSL
#            ...
# 7008    Fiber optic
# 7010    Fiber optic
# 7011            DSL
# 7026            DSL
# 7034    Fiber optic
# Name: InternetService, Length: 939, dtype: object>

# %% [markdown]
# 5. Total Charges

# %%
data["TotalCharges"].describe()
# Out:
# count    7043.000000
# mean     2290.520629
# std      2274.717686
# min        18.800000
# 25%       402.225000
# 50%      1400.300000
# 75%      3808.100000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# 5. a. Total Charges based on gender

# %%
D1=data[data["gender"] == "Male"]
D1
# Out:
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE   Male              0  ...          56.95      1889.50     No
# 2     3668-QPYBK   Male              0  ...          53.85       108.15    Yes
# 3     7795-CFOCW   Male              0  ...          42.30      1840.75     No
# 6     1452-KIOVK   Male              0  ...          89.10      1949.40     No
# 9     6388-TABGU   Male              0  ...          56.15      3487.95     No
# ...          ...    ...            ...  ...            ...          ...    ...
# 7033  9767-FFLEM   Male              0  ...          69.50      2625.25     No
# 7035  8456-QDAVC   Male              0  ...          78.70      1495.10     No
# 7038  6840-RESVB   Male              0  ...          84.80      1990.50     No
# 7041  8361-LTMKD   Male              1  ...          74.40       306.60    Yes
# 7042  3186-AJIEK   Male              0  ...         105.65      6844.50     No
#
# ...

# %%
D1["TotalCharges"].describe()
# Out:
# count    3555.000000
# mean     2291.680667
# std      2273.095299
# min        18.800000
# 25%       399.275000
# 50%      1406.000000
# 75%      3778.100000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
D2=data[data["gender"] == "Female"]
D2
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
#
# ...

# %%
D2["TotalCharges"].describe()
# Out:
# count    3488.000000
# mean     2289.338308
# std      2276.695359
# min        18.850000
# 25%       403.300000
# 50%      1389.050000
# 75%      3834.062500
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# 5. b. Total Charges based on contract

# %%
D3=data[data["Contract"]=="Month-to-month"]
D3
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 6     1452-KIOVK    Male              0  ...          89.10      1949.40     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7033  9767-FFLEM    Male              0  ...          69.50      2625.25     No
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7035  8456-QDAVC    Male              0  ...          78.70      1495.10     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
#
# ...

# %%
D3["TotalCharges"].describe()
# Out:
# count    3875.000000
# mean     1369.254581
# std      1613.879008
# min        18.850000
# 25%       160.100000
# 50%       679.550000
# 75%      2066.500000
# max      8061.500000
# Name: TotalCharges, dtype: float64

# %%
D4=data[data["Contract"]=="Two year"]
D4
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 11    7469-LKBCI    Male              0  ...          18.95       326.80     No
# 15    3655-SNQYZ  Female              0  ...         113.25      7895.15     No
# 17    9959-WOFKT    Male              0  ...         106.70      7382.25     No
# 23    3638-WEABW  Female              0  ...          59.90      3505.10     No
# 28    5248-YGIJN    Male              0  ...          90.25      6369.45     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7017  4807-IZYOZ  Female              0  ...          20.65      1020.75     No
# 7019  9710-NJERN  Female              0  ...          20.15       826.00     No
# 7028  9281-CEDRU  Female              0  ...          64.10      4326.25     No
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
D4["TotalCharges"].describe()
# Out:
# count    1695.000000
# mean     3746.752383
# std      2582.454154
# min        20.350000
# 25%      1280.125000
# 50%      3638.250000
# 75%      6044.300000
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %%
D5=data[data["Contract"]=="One year"]
D5
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 9     6388-TABGU    Male              0  ...          56.15      3487.95     No
# 12    8091-TTVAX    Male              0  ...         100.35      5681.10     No
# 16    8191-XWSZG  Female              0  ...          20.65      1022.95     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7022  7203-OYKCT    Male              0  ...         104.95      7544.30     No
# 7031  3605-JISKB    Male              1  ...          60.00      3316.10     No
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
#
# ...

# %%
D5["TotalCharges"].describe()
# Out:
# count    1473.000000
# mean     3038.377461
# std      2233.477741
# min        18.800000
# 25%       989.450000
# 50%      2658.400000
# 75%      4860.350000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# 5. c. Total Charges based on payment method

# %%
data["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
D6=data[data["PaymentMethod"]=="Electronic check"]
D6
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# 5     9305-CDSKC  Female              0  ...          99.65       820.50    Yes
# 8     7892-POOKP  Female              0  ...         104.80      3046.05    Yes
# 14    5129-JLPIS    Male              0  ...         105.50      2686.05     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7023  1035-IPQPU  Female              1  ...         103.50      6479.40     No
# 7029  2235-DWLJU  Female              1  ...          44.40       263.05     No
# 7032  6894-LFHLY    Male              1  ...          75.75        75.75    Yes
# 7036  7750-EYXWZ  Female              0  ...          60.65       743.30     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
#
# ...

# %%
D6["TotalCharges"].describe()
# Out:
# count    2365.000000
# mean     2090.868182
# std      2155.435320
# min        18.850000
# 25%       308.050000
# 50%      1253.900000
# 75%      3340.550000
# max      8564.750000
# Name: TotalCharges, dtype: float64

# %%
D7=data[data["PaymentMethod"]=="Mailed check"]
D7
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 1     5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 7     6713-OKOMC  Female              0  ...          29.75       301.90     No
# 10    9763-GRSKD    Male              0  ...          49.95       587.45     No
# 16    8191-XWSZG  Female              0  ...          20.65      1022.95     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7019  9710-NJERN  Female              0  ...          20.15       826.00     No
# 7027  0550-DCXLH    Male              0  ...          73.35       931.55     No
# 7030  0871-OPBXW  Female              0  ...          20.05        39.25     No
# 7038  6840-RESVB    Male              0  ...          84.80      1990.50     No
# 7041  8361-LTMKD    Male              1  ...          74.40       306.60    Yes
#
# ...

# %%
D7["TotalCharges"].describe()
# Out:
# count    1612.000000
# mean     1083.236973
# std      1509.101844
# min        18.800000
# 25%       116.937500
# 50%       473.675000
# 75%      1316.000000
# max      8476.500000
# Name: TotalCharges, dtype: float64

# %%
D8=data[data["PaymentMethod"]=="Bank transfer (automatic)"]
D8
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 9     6388-TABGU    Male              0  ...          56.15      3487.95     No
# 13    0280-XJGEX    Male              0  ...         103.70      5036.30    Yes
# 17    9959-WOFKT    Male              0  ...         106.70      7382.25     No
# 21    1680-VDCWW    Male              0  ...          19.80       202.25     No
# ...          ...     ...            ...  ...            ...          ...    ...
# 7026  8775-CEBBJ  Female              0  ...          44.20       403.35    Yes
# 7028  9281-CEDRU  Female              0  ...          64.10      4326.25     No
# 7035  8456-QDAVC    Male              0  ...          78.70      1495.10     No
# 7037  2569-WGERO  Female              0  ...          21.15      1419.40     No
# 7042  3186-AJIEK    Male              0  ...         105.65      6844.50     No
#
# ...

# %%
D8["TotalCharges"].describe()
# Out:
# count    1544.000000
# mean     3083.566023
# std      2360.362773
# min        19.250000
# 25%      1052.387500
# 50%      2479.500000
# 75%      4948.337500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
D9=data[data["PaymentMethod"]=="Credit card (automatic)"]
D9
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 6     1452-KIOVK    Male              0  ...          89.10      1949.40     No
# 11    7469-LKBCI    Male              0  ...          18.95       326.80     No
# 12    8091-TTVAX    Male              0  ...         100.35      5681.10     No
# 15    3655-SNQYZ  Female              0  ...         113.25      7895.15     No
# 18    4190-MFLUW  Female              0  ...          55.20       528.35    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7024  7398-LXGYX    Male              0  ...          84.80      3626.35     No
# 7031  3605-JISKB    Male              1  ...          60.00      3316.10     No
# 7033  9767-FFLEM    Male              0  ...          69.50      2625.25     No
# 7034  0639-TSIQW  Female              0  ...         102.95      6886.25    Yes
# 7039  2234-XADUH  Female              0  ...         103.20      7362.90     No
#
# ...

# %%
D9["TotalCharges"].describe()
# Out:
# count    1522.000000
# mean     3074.920894
# std      2410.536742
# min        19.300000
# 25%       989.400000
# 50%      2454.175000
# 75%      5016.550000
# max      8670.100000
# Name: TotalCharges, dtype: float64
